# %%
# %%time

from gensim.models.word2vec import Word2Vec
import pandas as pd
model = Word2Vec.load('./result_data/skipgram_model_10_20.model')
model.wv.most_similar('뷰좋', topn=30)
# Out:
# /Users/likealocal/opt/anaconda3/envs/py3env/lib/python3.8/site-packages/smart_open/smart_open_lib.py:400: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   warnings.warn(
# CPU times: user 763 ms, sys: 101 ms, total: 863 ms
# Wall time: 859 ms
# [('뷰깡패', 0.8223698139190674),
#  ('뷰카페', 0.8092208504676819),
#  ('뷰맛집', 0.8023385405540466),
#  ('전망', 0.7774059772491455),
#  ('뷰가', 0.7588638663291931),
#  ('경치', 0.7196053266525269),
#  ('호수뷰', 0.712670087814331),
#  ('카페뷰', 0.7050703763961792),
#  ('애뜨락', 0.7012084722518921),
#  ('미텐발트', 0.7008854150772095),
#  ('쐬기', 0.6992151737213135),
#  ('탁트인', 0.6880775690078735),
#  ('전망대', 0.6681047081947327),
#  ('날좋은날', 0.6618880033493042),
#  ('느그시봄', 0.6525382995605469),
#  ('좋으다', 0.6520509719848633),
#  ('물빛', 0.6503448486328125),
#  ('뷰최고', 0.6371492147445679),
# ...

# %%
model.wv.most_similar('경치', topn=30)
# Out:
# [('뷰가', 0.7770344614982605),
#  ('전경', 0.7579602003097534),
#  ('풍경이', 0.7565609216690063),
#  ('절경', 0.7478463649749756),
#  ('전망대', 0.7444721460342407),
#  ('뷰맛집', 0.7354600429534912),
#  ('해질녘', 0.7315371632575989),
#  ('뷰깡패', 0.7272714376449585),
#  ('운치', 0.726134717464447),
#  ('한적', 0.7252481579780579),
#  ('내려다', 0.7248828411102295),
#  ('뷰좋', 0.7196054458618164),
#  ('여유로움', 0.7150715589523315),
#  ('좋다', 0.7142046093940735),
#  ('오성제', 0.7119865417480469),
#  ('고즈넉', 0.7104190587997437),
#  ('전망', 0.707260012626648),
#  ('좋네', 0.7065002918243408),
#  ('한적한', 0.705602765083313),
#  ('석양', 0.7055209875106812),
#  ('노을', 0.7011384963989258),
#  ('뷰도', 0.6999738812446594),
#  ('마운틴뷰', 0.6948084831237793),
#  ('내려다본', 0.6884440183639526),
#  ('뷰카페', 0.6882256865501404),
#  ('탁트인', 0.687934398651123),
#  ('동고사', 0.6872839331626892),
#  ('연꽃', 0.6863572001457214),
#  ('풍경', 0.6812926530838013),
#  ('바라본', 0.680259644985199)]

# %%
model.wv.most_similar('테라스', topn=30)
# Out:
# [('루프탑', 0.6578055620193481),
#  ('테라스에', 0.5953692197799683),
#  ('전망', 0.5906972885131836),
#  ('옥상', 0.5808621644973755),
#  ('뷰가', 0.5760582685470581),
#  ('카페', 0.57097327709198),
#  ('잔디밭', 0.5707123279571533),
#  ('커피가맛있는집', 0.5706802606582642),
#  ('루프탑에', 0.5689988136291504),
#  ('운동장', 0.5685656070709229),
#  ('뷰카페', 0.5669202208518982),
#  ('베라노', 0.5632736086845398),
#  ('햇살', 0.5591260194778442),
#  ('뷰깡패', 0.5590373277664185),
#  ('잔디', 0.5583517551422119),
#  ('창가', 0.5562193989753723),
#  ('통창', 0.5559265613555908),
#  ('분위기', 0.5520384311676025),
#  ('에이트플로어', 0.5517299175262451),
#  ('아메리카노', 0.5399463176727295),
#  ('뷰좋', 0.5390353798866272),
#  ('상공회의소옆', 0.5385129451751709),
#  ('탁트인', 0.5364810228347778),
#  ('카페로', 0.5339575409889221),
#  ('카페테리아', 0.5314188003540039),
#  ('뷰맛집', 0.5298380851745605),
#  ('유치원', 0.5287315845489502),
#  ('임실카', 0.5274302363395691),
#  ('까페', 0.5263139605522156),
#  ('통유리', 0.5238372087478638)]
